# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishpatel26/Pytorch-Learning-/blob/main/Pytorch_Basic_Introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pytorch Introduction
# ---
# PyTorch is an open source machine learning library for Python, based on Torch,used for applications such as natural language processing.It is primarily developed by Facebook's artificial-intelligence research group, and Uber's "Pyro" software for probabilistic programming is built on it.
#
# **PyTorch provides two high-level features:**
# * Tensor computation (like NumPy) with strong GPU, TPU Support
# * Deep Neural Networks built on a tape-based autodiff system
#
# ---
# Environment Configuration
# ---
# ![PytorchInstallation.png](data:image/png;base64,...)

# %% [markdown]
# * [Step by Step Pytorch Installation Walkthrough on Windows](https://www.superdatascience.com/blogs/pytorch-windows-installation-walkthrough)

# %% [markdown]
# ## Cuda Version Check

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243

# %% [markdown]
# ## Installation of Pytorch

# %%
# !pip install torch==1.7.1+cu101 torchvision==0.8.2+cu101 torchaudio==0.7.2 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...

# %%
import torch
print(torch.__version__)
# Out:
# 1.7.1+cu101
